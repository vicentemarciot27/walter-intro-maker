# %%
from langchain_aws import ChatBedrock
import os

claude_3_7_bedrock = ChatBedrock(
    model_id="arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    provider="anthropic",
    model_kwargs={"max_tokens": 20000,
    # "thinking": {"type": "enabled", "budget_tokens": 1024}
    },
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
)

claude_3_7_bedrock_thinking = ChatBedrock(
    model_id="arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    provider="anthropic",
    model_kwargs={"max_tokens": 20000,
    "thinking": {"type": "enabled", "budget_tokens": 1024}
    },
)

# %%
claude_3_7_bedrock.invoke("Hello, how are you?")
# Out:
# AIMessage(content="I'm doing well, thank you for asking! I'm here and ready to assist you with information or help with whatever you'd like to discuss today. How can I help you?", additional_kwargs={'usage': {'prompt_tokens': 13, 'completion_tokens': 40, 'total_tokens': 53}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0'}, response_metadata={'usage': {'prompt_tokens': 13, 'completion_tokens': 40, 'total_tokens': 53}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'arn:aws:bedrock:us-east-1:050451404360:inference-profile/us.anthropic.claude-3-7-sonnet-20250219-v1:0'}, id='run-8a3c17a3-e54e-47fc-86ef-0c79a4bb134d-0', usage_metadata={'input_tokens': 13, 'output_tokens': 40, 'total_tokens': 53})

# %%
from langgraph.graph import END, StateGraph
from typing import Literal, TypedDict, List
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ## GSheets

# %%
# login using service account
from google.oauth2 import service_account
import pandas as pd
import gspread
from gspread_pandas import Spread

# Configurar credenciais
credentials = service_account.Credentials.from_service_account_file(
    ".secrets/service-account-admin.json",
    scopes=['https://www.googleapis.com/auth/spreadsheets', 
            'https://www.googleapis.com/auth/drive']
)

# Conectar ao Google Sheets
gc = gspread.authorize(credentials)

# Extrair o ID da planilha da URL
sheet_id = "11I9QFSMFn7UBfV0wz0-hAYgWtIKytTVnWA9pjquwgdk"

# Abrir a planilha e obter a primeira aba
sheet = gc.open_by_key(sheet_id).sheet1

# Obter todos os dados e converter para DataFrame
data = sheet.get_all_values()
headers = data[0]
df = pd.DataFrame(data[1:], columns=headers)

# Exibir as primeiras linhas do DataFrame
df.head(3)
# Out:
#                   name proximity industry_agnostic              leader?  \
# 0         Bridge Latam         3              TRUE        Pure-follower
# 1              Latitud         3              TRUE        Pure-follower
# 2  Andreessen Horowitz         3              TRUE  Leader and Follower
#
#   investment_geography preferred_industry vc_quality_perception  \
# 0                Latam                 []                   3.0
# 1                Latam                 []                   4.0
# 2               Global                 []                   5.0
#
#                                         observations  \
# 0                  Agnostic, low bar for investments
# 1  Top-tier pre-seed dealflow. Have an active acc...
# 2                         Focusing more on Series A+
#
#                                    investment_range       geo_origin  ...    \
# 0                                       [< USD 1mn]  Latam ex-Brazil  ...
# 1                            [< USD 1mn, USD 1-5mn]           Brazil  ...
# 2  [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]    Outside Latam  ...
#
#   Opiniao Cache investor_profile  \
# 0                             VC
# 1                             VC
# 2                             VC
#
#                           prefered_industry_enriched meeting_frequency  \
# 0  Business/Productivity Software, Financial Soft...       [Bimonthly]
# 1  Fintech, vertical SaaS, Healthtech, Marketplac...         [Monthly]
# 2  (Global: AI, Bio + Healthcare, Consumer, Crypt...         [Monthly]
#
#   intros_made intros_received  \
# 0        14.0              16
# 1        13.0            13.0
# 2        14.0             3.0
#
#                                          description        domains  \
# 0  Bridge Partners is an early-stage investment f...  bridgelat.com
# 1  Latitud is the operating system for Latin Amer...    latitud.com
# 2  Andreessen Horowitz is a venture capital firm ...       a16z.com
#
#                                entry_id
# 0  007037bc-f043-424c-a9ef-0d7394eeed90
# 1  009e1d00-ddaa-4e35-8113-3b775dfe46c7
# 2  082a298f-a986-4686-becb-9905d63a806b
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Gdocs

# %%
# Importar bibliotecas necessárias para Google Docs
from googleapiclient.discovery import build
from google.oauth2 import service_account

# Configurar credenciais para Google Docs (usando as mesmas credenciais do Sheets)
SCOPES = ['https://www.googleapis.com/auth/documents.readonly']
creds = service_account.Credentials.from_service_account_file(
    '.secrets/service-account-admin.json',
    scopes=SCOPES
)

# Criar serviço do Google Docs
docs_service = build('docs', 'v1', credentials=creds)

# Função para obter conteúdo de um documento do Google Docs
def get_gdoc_content(doc_id):
    """
    Obtém o conteúdo de um documento do Google Docs pelo ID.
    
    Args:
        doc_id (str): ID do documento do Google Docs
        
    Returns:
        dict: Conteúdo do documento
    """
    try:
        # Fazer a requisição para obter o documento
        document = docs_service.documents().get(documentId=doc_id).execute()
        return document
    except Exception as e:
        print(f"Erro ao acessar o documento: {e}")
        return None


doc_ids = ["1WJDSO_uyTJ16DdkDOhgAUww4bMKuUa9fXuTh0HdkOew", "1F8jqD4pFq3_17NN75HZbzd2G2vrIqWaZqR1MOB5Fa6M", "182Qj0a8ZIXjS0_plWZdRY-aGY-X8qqpiIAUYex8xrd0"]
for doc_id in doc_ids:
    doc_content = get_gdoc_content(doc_id)
    if doc_content:
        print(f"Título do documento: {doc_content.get('title')}")
# Out:
# Título do documento: [AI MATERIAL] Definition of Lead and Follow
# Título do documento: [AI MATERIAL] Geographic Focus
# Título do documento: [AI MATERIAL] Preffered Industry

# %%
# Extrair texto do documento
doc_plaintext = ""
for item in doc_content.get('body').get('content'):
    if 'paragraph' in item:
        for element in item.get('paragraph').get('elements', []):
            if 'textRun' in element:
                doc_plaintext += element.get('textRun').get('content', '')

doc_plaintext
# Out:
# 'Analysis of Venture Capital Investment Preferences in Latin America\n1. Executive Summary\nThis report analyzes the preferred investment industries of a selected group of venture capital firms with a significant presence or interest in the Latin American market. The analysis reveals a strong concentration of investment in the technology sector, particularly within software-as-a-service (SaaS), financial technology (Fintech), and e-commerce enablers. While many firms exhibit a broad interest across various technology verticals, some demonstrate specialization in areas such as agritech, edtech, and climate technology. The findings highlight the dynamism and increasing maturity of the Latin American venture capital ecosystem, attracting both regional and global investors who are keen to capitalize on the region\'s burgeoning entrepreneurial landscape. Understanding these investment preferences is crucial for entrepreneurs seeking funding and for investors looking to identify key opportunities within this rapidly evolving market.\n2. Introduction: The Latin American Venture Capital Landscape\nThe venture capital ecosystem in Latin America has experienced significant growth and transformation in recent years, evolving from a nascent stage to a vibrant and increasingly attractive destination for global capital. The period around 2021 and 2022 marked a substantial inflection point, with investment volumes reaching unprecedented levels, dwarfing the cumulative investments of the preceding decade . This surge in activity underscores the growing recognition of the immense potential within the Latin American startup scene. However, it is crucial to acknowledge the inherent diversity of this landscape. What might prove successful in the Brazilian market, the largest in the region, may not necessarily translate to the unique dynamics of Mexico or the Spanish-speaking nations . Each country possesses its own distinct market characteristics, regulatory frameworks, and consumer behaviors, necessitating a nuanced understanding for effective investment strategies. This report delves into the investment preferences of several key venture capital firms active in Latin America, aiming to provide a comprehensive overview of the current trends and areas of focus within this dynamic ecosystem.  \n3. Investment Preferences of Key Venture Capital Firms in Latin America\n3.1. Bridge Latam\nEstablished in 2021 and headquartered in Mexico City, Bridge Latam operates as a venture capital investment firm with a clear focus on early-stage startups within the Latin American technology sector . The firm\'s emergence during a period of heightened venture capital activity in the region signifies the ongoing expansion of the investment landscape and the creation of new avenues for entrepreneurs seeking early funding. Bridge Latam\'s investment portfolio reveals a particular interest in sectors such as Business/Productivity Software, Financial Software, and Human Capital Services . This indicates a belief in the potential of technology to drive efficiency and innovation across various enterprise functions. Beyond its direct venture investments, Bridge Latam\'s involvement in market analysis, sourcing, and business development across Consumer Goods, Luxury Goods, and Capital Goods suggests a broader understanding of the Latin American market. This connection could imply a strategic approach to identifying and supporting technology solutions that can effectively address the needs and challenges within these more traditional industries. The firm\'s investment thesis centers on backing startups that demonstrate strong technological potential and the capacity for significant scalability, with a notable emphasis on the quality and vision of the founding team . With typical initial investments ranging from USD $200,000 to USD $500,000 , Bridge Latam positions itself as a key supporter of early-stage innovation in Latin America. In essence, Bridge Latam is an early-stage ...

# %% [markdown]
# ## AI

# %%
inputs = {
    "company": "Brendi",
    "description_company": "Brendi is a company that creates AI agents to sell food in Brazilian restaurants via delivery. They are going to be the next ifood",
    "description_person": "Daniel is the CEO of Brendi. he studied at ITA, is very young and energetic",
    "round": {"size": "10M USD", "Funding": "Series A"},
    "round_commitment": "2M USD",
    "leader_or_follower": "leader",
    "industry": "AI Solutions, Food Delivery, Restaurant Management, AI Agents, Embedded Finance",
    "fund_closeness": "Close",
    "observations": "We are sure this deal is very hot, so we want the top funds with us in this one, but they have to fit"
}

parameters = {
    "batch_size": 10,
    "surviving_percentage": 0.5,
}

# %%
# First Filter
if inputs["leader_or_follower"] == "leader":
    # get only leader? that contains the word Leader (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("leader")]
else:
    # get only follower? that contains the word Follower (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("follower")]

# %%
from pydantic import BaseModel
class FundScore(TypedDict):
    fund_name: str
    score: float
    reason: str

class FundScoreList(BaseModel):
    scores: List[FundScore]

class AgentState(TypedDict):
    df: pd.DataFrame
    df_batches: list[pd.DataFrame]
    fund_scores: list[FundScore]
    raw_scores: List[FundScore]  # Armazenar pontuações não normalizadas
    second_raw_scores:List[FundScore]
    second_scores: List[FundScore]


BATCH_SIZE = 10
SURVIVING_PERCENTAGE = 0.5

# %%
df
# Out:
#                        name proximity industry_agnostic              leader?  \
# 2       Andreessen Horowitz         3              TRUE  Leader and Follower
# 3                  big_bets         5                    Leader and Follower
# 4             NXTP Ventures         3                                 Leader
# 5           Alexia Ventures         4                    Leader and Follower
# 7             Volpe Capital         2              TRUE  Leader and Follower
# 8          Citrino Ventures         3              TRUE  Leader and Follower
# 9              30N Ventures         3                    Leader and Follower
# 10  Across Capital Partners         4                    Leader and Follower
# 11                   Amador         3                    Leader and Follower
# 12                SaaSholic         3                    Leader and Follower
# 14            Dalus Capital         1                    Leader and Follower
# 15            Credit Saison         5                    Leader and Follower
# 16                    Zenda         3                    Leader and Follower
# 17                    ONEVC         5                    Leader and Follower
# 18             Fen Ventures         4                    Leader and Follower
# 24                   Kayyak         2                    Leader and Follower
# 25             MAYA Capital         5                    Leader and Follower
# 27                      DGF         3                    Leader and Follower
# 29              Hi Ventures         1                                 Leader
# 30                 Headline         1             FALSE               Leader
# 31                 Tantauco         2                    Leader and Follower
# 33                  Bewater         4                    Leader and Follower
# 34                 Tidemark         1                    Leader and Follower
# 35              HOF Capital         3                    Leader and Follower
# 36            Quona Capital         3             FALSE  Leader and Follower
# 37                   Kaszek         4                                 Leader
# 38                Monashees         4                    Leader and Follower
# 39                   Canary         3                    Leader and Follower
# 40               DST Global         2                    Leader and Follower
# 41           Magma Partners         3                    Leader and Follower
# 42             500 Startups         3                    Leader and Follower
# 43  Propel Venture Partners         2                    Leader and Follower
# 44      Valor Capital Group         4                    Leader and Follower
# 45         Caravela Capital         4                    Leader and Follower
# 47                Cometa VC         1                    Leader and Follower
# 49                  Astella         4                                 Leader
# 51             Alter Global         5                    Leader and Follower
# 52                   Upload         3              TRUE  Leader and Follower
# 53                Atlantico         4              TRUE  Leader and Follower
# 54        Flourish Ventures         2             FALSE  Leader and Follower
# 55        J.P. Morgan & Co.         1                    Leader and Follower
# 57                   Tekton         1                    Leader and Follower
#
#              investment_geography  \
# 2                          Global
# 3                     Brazil, USA
# 4                           Latam
# 5                           Latam
# 7                           Latam
# 8                          Brazil
# 9                           Latam
# 10                         Global
# 11                          Latam
# 12                          Latam
# 14                          Latam
# 15                         Global
# 16                          Latam
# 17                          Latam
# 18                          Latam
# 24                          Latam
# 25                          Latam
# 27                          Latam
# 29                          Latam
# 30                         Global
# 31                          Latam
# 33                          Latam
# 34                    Global, USA
# 35                         Global
# 36       Global, Emerging Markets
# 37                          Latam
# 38                          Latam
# 39                          Latam
# 40                         Global
# 41                          Latam
# 42                         Global
# 43                     Global, US
# 44             Global, Brazil, US
# 45                         Brazil
# 47  Spanish-speaking markets, USA
# 49                         Brazil
# 51       Global, Emerging Markets
# 52                         Global
# 53                  Latam, Brazil
# 54       Global, Emerging Markets
# 55                         Global
# 57
#
#                                    preferred_industry vc_quality_perception  \
# 2                                                  []                   5.0
# 3                                                  []                   4.0
# 4                                                  []                   4.0
# 5                                                  []                   4.0
# 7                                                  []                   3.0
# 8                                                  []                   3.0
# 9                                                  []                   2.0
# 10                                                 []                   4.0
# 11            [B2B SaaS, Fintech, Healthtech, Edtech]                   2.0
# 12                                                 []                   3.0
# 14   [Healthtech, Mobility and Supply Chain, Climate]                   3.0
# 15      [Fintech, Web 3.0, E-commerce & Market Place]                   3.0
# 16  [Fintech, Logistics & Mobility, Healthtech, AI...                   3.0
# 17                                                 []                   5.0
# 18                                                 []                   3.0
# 24                                                 []                   3.0
# 25                                                 []                   5.0
# 27                                                 []                   3.0
# 29                                                 []                   4.0
# 30                                                 []                   3.0
# 31                                                 []
# 33                                                 []                   2.0
# 34                                                 []                   5.0
# 35                                                 []                   3.0
# 36                                                 []                   4.0
# 37                                                 []                   5.0
# 38                                                 []                   5.0
# 39                                                 []                   5.0
# 40                                                 []                   5.0
# 41                 [Fintech, Insurtech, Marketplaces]                   2.0
# 42                                                 []
# 43                                                 []                   3.0
# 44                                                 []                   5.0
# 45                                                 []                   3.0
# 47                                                 []
# 49                                                 []                   4.0
# 51                                                 []                   3.0
# 52                                                 []                   4.0
# 53                                                 []                   4.0
# 54                                          [Fintech]                   4.0
# 55                                [Fintech, B2B SaaS]
# 57
#
#                                          observations  \
# 2                          Focusing more on Series A+
# 3                            Brazil and Global thesis
# 4      B2B focused, Fintech, Marketplace, Ecommerce.
# 5                              SaaS and AI businesses
# 7                                      Needs traction
# 8   B2B, Agnostic. Seed, early, and later-stage, B...
# 9                                            Follower
# 10               >USD 5M of ARR, with +50% YoY growth
# 11  VC & PE (Financial Services, Logistics, Consum...
# 12                     B2B businesses, low valuations
# 14  Focuses on technology, healthcare, climate, an...
# 15
# 16  Fintech, Logistics & Mobility, Healthtech, AI ...
# 17                 Solo players, rising top-tier fund
# 18
# 24  Founded in 2020, First fund ~USD 100M, Second ...
# 25             Solo players, getting closer over time
# 27                                       B2B Software
# 29  Fundo 4 de USD 47M, estão querendo fazer mais ...
# 30               Out of the mainstream, PE-like deals
# 31                 Latam - Fintech, SaaS, marketplace
# 33
# 34                                      ARR > USD 10M
# 35                             Fintech, Global theses
# 36               Fintech and Social Impact businesses
# 37                                      Top-tier fund
# 38                                      Top-tier fund
# 39                                  Pre-op businesses
# 40
# 41    Fintech, Insurtech, Marketplaces, Latin America
# 42                            Investem USD 300k @ 10%
# 43
# 44  Top-tier fund. We like them on Web3 and Crypto...
# 45                                   Lower valuations
# 47
# 49                        Specialists in GTM Strategy
# 51               Fintech, B2B, proven business models
# 52                        Agnostic, across all stages
# 53                                           Agnostic
# 54  Early-stage, improving financial health & pros...
# 55  Potencial investidor do nosso Fintech Managed ...
# 57
#
#                                      investment_range       geo_origin  ...    \
# 2    [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]    Outside Latam  ...
# 3                              [< USD 1mn, USD 1-5mn]           Brazil  ...
# 4                              [USD 1-5mn, < USD 1mn]  Latam ex-Brazil  ...
# 5     [< USD 1mn, USD 1-5mn, USD 5-10mn, USD 10-20mn]           Brazil  ...
# 7                             [USD 5-10mn, USD 1-5mn]           Brazil  ...
# 8                                         [USD 1-5mn]           Brazil  ...
# 9                             [USD 1-5mn, USD 5-10mn]  Latam ex-Brazil  ...
# 10                          [USD 5-10mn, USD 10-20mn]           Brazil  ...
# 11                                        [< USD 1mn]    Outside Latam  ...
# 12                             [< USD 1mn, USD 1-5mn]           Brazil  ...
# 14                             [< USD 1mn, USD 1-5mn]  Latam ex-Brazil  ...
# 15                                                 []    Outside Latam  ...
# 16                                        [< USD 1mn]  Latam ex-Brazil  ...
# 17                 [< USD 1mn, USD 1-5mn, USD 5-10mn]           Brazil  ...
# 18                                                 []  Latam ex-Brazil  ...
# 24                 [< USD 1mn, USD 1-5mn, USD 5-10mn]  Latam ex-Brazil  ...
# 25                 [< USD 1mn, USD 1-5mn, USD 5-10mn]           Brazil  ...
# 27                             [USD 1-5mn, < USD 1mn]           Brazil  ...
# 29                                        [USD 1-5mn]  Latam ex-Brazil  ...
# 30                            [USD 1-5mn, USD 5-10mn]           Brazil  ...
# 31                                                 []  Latam ex-Brazil  ...
# 33                                                 []           Brazil  ...
# 34              [USD 10-20mn, > USD 20mn, USD 5-10mn]    Outside Latam  ...
# 35   [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]    Outside Latam  ...
# 36                            [USD 1-5mn, USD 5-10mn]    Outside Latam  ...
# 37  [< USD 1mn, USD 1-5mn, USD 10-20mn, USD 5-10mn...           Brazil  ...
# 38  [< USD 1mn, USD 1-5mn, USD 5-10mn, USD 10-20mn...           Brazil  ...
# 39                             [< USD 1mn, USD 1-5mn]           Brazil  ...
# 40  [< USD 1mn, USD 1-5mn, USD 5-10mn, USD 10-20mn...    Outside Latam  ...
# 41                                                 []                   ...
# 42                                        [< USD 1mn]  Latam ex-Brazil  ...
# 43                                        [USD 1-5mn]  Latam ex-Brazil  ...
# 44  [< USD 1mn, USD 1-5mn, USD 5-10mn, USD 10-20mn...           Brazil  ...
# 45                                        [< USD 1mn]           Brazil  ...
# 47                                                 []                   ...
# 49    [< USD 1mn, USD 1-5mn, USD 5-10mn, USD 10-20mn]           Brazil  ...
# 51                                        [< USD 1mn]    Outside Latam  ...
# 52                             [USD 1-5mn, < USD 1mn]           Brazil  ...
# 53                            [USD 1-5mn, USD 5-10mn]           Brazil  ...
# 54                                        [USD 1-5mn]                   ...
# 55                                                 []    Outside Latam  ...
# 57                                                                      ...
#
#    Opiniao Cache investor_profile  \
# 2                              VC
# 3                              VC
# 4                              VC
# 5                              VC
# 7                              VC
# 8                   Family office
# 9                              VC
# 10                             VC
# 11                             VC
# 12                             VC
# 14                             VC
# 15                            CVC
# 16                             VC
# 17                             VC
# 18                             VC
# 24                             VC
# 25                             VC
# 27                             VC
# 29                             VC
# 30                             VC
# 31                             VC
# 33                             VC
# 34                             VC
# 35                             VC
# 36                             VC
# 37                             VC
# 38                             VC
# 39                             VC
# 40                             VC
# 41                             VC
# 42                             VC
# 43                             VC
# 44                             VC
# 45                             VC
# 47                             VC
# 49                             VC
# 51                             VC
# 52                             VC
# 53                             VC
# 54                             VC
# 55                             VC
# 57
#
#                            prefered_industry_enriched meeting_frequency  \
# 2   (Global: AI, Bio + Healthcare, Consumer, Crypt...         [Monthly]
# 3   Software (IDtech, AI, SaaS, Fintech, Edtech, G...         [Monthly]
# 4   Cloud & SaaS, E-commerce Enablers, Fintech, B2...         [Monthly]
# 5   Software Platforms, Data/AI, Blockchain/Crypto...         [Monthly]
# 7   FinTech, SaaS, Marketplaces, Healthtech, Const...       [Quarterly]
# 8   Agriculture (AgTech), Education (EdTech), Fina...       [Bimonthly]
# 9   Fintech, Foodtech, Retailtech (Marketplace, E-...       [Bimonthly]
# 10  Software (Financial Software, Legal Services B...       [Bimonthly]
# 11  Digital-enabled business models, Tech-enabled ...       [Bimonthly]
# 12  SaaS, other tech-related (Future of Work, Mobi...         [Monthly]
# 14  Technology, Climate Innovation, Business Produ...       [Bimonthly]
# 15  All Verticals (focus on Fintech, E-commerce, W...       [Bimonthly]
# 16  Healthcare, Financial Services, Business Produ...       [Bimonthly]
# 17  Fintech, SaaS, Logistics, Proptech, Biotechnol...       [Bimonthly]
# 18  Digital Consumer (Home, Entertainment, Healthc...       [Bimonthly]
# 24  Broad focus on technology solving Latin Americ...       [Bimonthly]
# 25  Technology (Marketplace, E-commerce, FinTech, ...         [Monthly]
# 27                                                          [Bimonthly]
# 29                                                          [Bimonthly]
# 30                            Growth-stage Technology       [Bimonthly]
# 31  Finance Technology, Marketplaces, SaaS, Blockc...       [Bimonthly]
# 33  No specific industries identified (LatAm), Var...         [Monthly]
# 34  Vertical SaaS (Cannabis, Content & E-commerce,...       [Bimonthly]
# 35  Leverages network across traditional industrie...       [Quarterly]
# 36  Fintech inclusivo (serviços financeiros para n...         [Monthly]
# 37  Amplo espectro de tecnologia: fintech (cerca d...         [Monthly]
# 38  Diversos setores de tecnologia de alto impacto...         [Monthly]
# 39  Tecnologia early-stage variada: destaque para ...         [Monthly]
# 40  Internet consumer e fintech em estágio de cres...       [Bimonthly]
# 41  Forte ênfase em fintech, insurtech e proptech,...       [Bimonthly]
# 42  Abrangente – Portfólio global com SaaS, mobile...       [Bimonthly]
# 43  Fintech e novas finanças – Foco dedicado em st...       [Bimonthly]
# 44  Fintech, enterprise, Crypto e Web3 são destaqu...         [Monthly]
# 45  Tecnologia early-stage generalista, mirando st...         [Monthly]
# 47  Startups de tecnologia voltadas ao mercado his...       [Quarterly]
# 49  Não há foco setorial único – o critério princi...       [Bimonthly]
# 51  Startups em mercados emergentes (LatAm, Ásia, ...         [Monthly]
# 52  Tecnologia na AL com viés global, especialment...         [Monthly]
# 53  Tecnologia early-stage na América Latina em am...         [Monthly]
# 54  Fintech com propósito – investe somente em emp...       [Bimonthly]
# 55  Amplo espectro de setores estratégicos, reflet...       [Bimonthly]
# 57  Tekton Ventures invests in seed to early-stage...
#
#    intros_made intros_received  \
# 2         14.0             3.0
# 3         18.0            44.0
# 4         17.0             6.0
# 5         29.0            13.0
# 7          7.0             1.0
# 8         13.0             1.0
# 9          1.0             0.0
# 10         8.0             0.0
# 11         5.0             4.0
# 12        15.0             8.0
# 14         7.0             0.0
# 15        12.0             0.0
# 16        18.0               3
# 17        23.0             6.0
# 18         1.0             1.0
# 24         1.0             0.0
# 25        25.0              20
# 27        20.0             8.0
# 29         4.0             0.0
# 30        13.0             1.0
# 31         3.0             0.0
# 33        12.0             3.0
# 34                         0.0
# 35        14.0             2.0
# 36        16.0             4.0
# 37        27.0             9.0
# 38        18.0            23.0
# 39        28.0              11
# 40         2.0             0.0
# 41         4.0             1.0
# 42         3.0             1.0
# 43         9.0             2.0
# 44        32.0            19.0
# 45        30.0            17.0
# 47         4.0             0.0
# 49        41.0              28
# 51        12.0             5.0
# 52        20.0             8.0
# 53        13.0             6.0
# 54                         0.0
# 55
# 57
#
#                                           description                domains  \
# 2   Andreessen Horowitz is a venture capital firm ...               a16z.com
# 3   big_bets is a venture capital and private equi...         bigbets.com.br
# 4   NXTP Ventures is a pioneering early stage vent...                nxtp.vc
# 5   Alexia Ventures is a venture capital firm that...              alexia.vc
# 7   Volpe Capital is a venture capital and private...       volpecapital.com
# 8   Citrino Ventures is a VC firm that supports vi...             citrino.vc
# 9   30N Ventures is a VC firm focused on Emerging ...                 30n.vc
# 10  Across Capital Partners partners with ambitiou...          acrosscap.com
# 11  Amador Holdings is an investment holding compa...        amador.holdings
# 12  SaaSholic is an early stage VC firm investing ...          saasholic.com
# 14  Dalus Capital is an international venture capi...       daluscapital.com
# 15  Saison Capital focuses on supporting innovativ...    creditsaison-br.com
# 16  Zenda is a thesis-driven tech investment firm ...               zenda.vc
# 17  ONEVC is a venture capital firm based in Latam...               onevc.vc
# 18  Fen Ventures: Early stage VC partnering with t...        fenventures.com
# 24  Kayyak Venture Capital is an impact investing ...     kayyakventures.com
# 25  MAYA CAPITAL is an early-stage investment fund...           maya.capital
# 27  DGF is a top Brazilian venture capital investo...             dgf.com.br
# 29  allvp (hi.vc) is a Mexican venture capital fun...                  hi.vc
# 30  Headline (formerly e.ventures) is a Venture Ca...           headline.com
# 31  Tantauco Ventures, a venture capital firm dedi...            daedalus.vc
# 33  Bewater is a venture capital firm that special...             bewater.vc
# 34  Tidemark is a growth equity firm dedicated to ...        tidemarkcap.com
# 35  HOF Capital is a global venture capital firm b...         hofcapital.com
# 36  Quona Capital invests in fintech innovators in...              quona.com
# 37  Kaszek is a venture capital firm founded in 20...             kaszek.com
# 38  monashees focuses on supporting passionate fou...       monashees.com.br
# 39  Canary serves as a co-founding partner for sta...          canary.com.br
# 40  DST Global is a prominent Internet investment ...         dst-global.com
# 41  Magma Partners is a venture capital firm speci...      magmapartners.com
# 42  500 Startups is a global venture capital firm ...                 500.co
# 43  Propel Venture Partners is a Bay Area-based fi...              propel.vc
# 44  Valor Capital Group is a pioneering cross-bord...  valorcapitalgroup.com
# 45  Caravela Capital: Brazilian VC firm backing ea...       caravela.capital
# 47  COMETA is a venture capital firm that invests ...              cometa.vc
# 49  Astella is a Brazilian Venture Capital firm th...      astellainvest.com
# 51  Alter Global is a venture capital firm that in...           alter.global
# 52  Upload is a venture capital firm operating in ...        upload.ventures
# 53  Atlantico is a venture capital and private equ...           atlantico.vc
# 54  Flourish Ventures is an early-stage global ven...   flourishventures.com
# 55  J.P. Morgan & Co. specializes in providing inv...           jpmorgan.com
# 57  Tekton Ventures is a seed-stage investment fir...
#
#                                 entry_id
# 2   082a298f-a986-4686-becb-9905d63a806b
# 3   0920744a-6cdf-4992-9ecd-f370cb240be6
# 4   099a7873-7123-4eb9-8397-6e629e61953c
# 5   0b184e1c-3f6e-4c24-b0b7-5d39ac18a8a9
# 7   1515b03e-826c-4ba5-92c4-e6a653a42067
# 8   15f7a23f-2eb0-4363-9c5f-a561842e6f61
# 9   17013bf6-7fb3-4011-8758-08a72bf23875
# 10  176e8b6f-bc56-4fb9-9275-b098084a96b6
# 11  190d0130-d61a-41fa-b86d-7802555e075a
# 12  1a89537c-1147-43d2-9e5f-046e10da584f
# 14  1dc017fd-9865-475e-9a6f-f16068940de8
# 15  26cc304b-ecc7-4e4f-b5a2-a93ac8eb0ae7
# 16  37b17e4a-4825-4319-b602-645c3351bbdb
# 17  3989b2b9-cb06-4ee5-938f-6a119dd8c65d
# 18  41340153-90bc-4f59-8c3f-73ec769ba631
# 24  5372296c-11fd-41b9-8ac1-79a8493a8803
# 25  58a6e1d8-cf52-4711-b006-475cae39fddf
# 27  6112205e-52b0-4ba7-b46a-ef2fbacd8d64
# 29  71194337-8360-437c-a5de-daa25637b7f9
# 30  7d62afe2-3576-4410-8770-17dbc24f37b0
# 31  878d4cc0-b299-4400-9ad9-3e09f54861ed
# 33  8dc09708-1b8a-4198-8879-d803656c85ee
# 34  91bc4602-ed07-47cc-a575-5dda39055c7a
# 35  9985e4c4-6437-4535-9883-e104f13d517a
# 36  a26f8ffd-b336-41e9-9ce1-ee52a6c484d5
# 37  a6f759b6-0df6-4fd4-ad30-f4bcb185fb4e
# 38  a75c73ce-844e-4618-99a2-2586dcca5b3e
# 39  a7678825-38e6-4e75-a6d5-dceefc66f3f1
# 40  aad2356f-dad7-4d30-9219-beaf9611f905
# 41  ac8d2109-e2fd-4220-beab-422f006614a0
# 42  b251cc14-36bb-4742-9954-58902ccd8711
# 43  b302beb1-d22f-4e3e-963c-c9b99f022254
# 44  b4e90b90-0161-483d-8cbf-0d0ab07d4667
# 45  bbb8817d-6ea4-45a5-bf46-d37a7ee852dc
# 47  cabd0f98-406a-409f-8e2f-68dd45d8c968
# 49  dda39278-bdbf-4254-b39b-916e1087a099
# 51  f1a07bbe-2b0e-4d51-b621-81f3733a799d
# 52  f24eb1e2-541d-46d8-863b-2366f21a160c
# 53  f7ecc5b4-4822-422d-8a76-c00fee1eb5b2
# 54  fac656b3-fe5c-46fa-b75c-8762c4e8b1e4
# 55  ff66c707-3acc-4a54-9b69-12e4d5d9d2ac
# 57
#
# [42 rows x 21 columns]

# %%
if inputs["fund_closeness"] == "Close":
    proximity_weight = 2
elif inputs["fund_closeness"] == "Distant":
    proximity_weight = -2
else:
    proximity_weight = 0

if inputs["fund_quality"] == "High":
    fund_quality_weight = 2
elif inputs["fund_quality"] == "Medium":
    fund_quality_weight = 1
elif inputs["fund_quality"] == "Low":
    fund_quality_weight = -1
else:
    fund_quality_weight = 0

weights = {
    "proximity": proximity_weight,
    "investment_geography": 1,
    "fund_quality": fund_quality_weight,
    "round_compatibility": 1,
    "description_compatibility": 1,
}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 8
#       5 else:
#       6     proximity_weight = 0
# ----> 8 if inputs["fund_quality"] == "High":
#       9     fund_quality_weight = 2
#      10 elif inputs["fund_quality"] == "Medium":
#
# KeyError: 'fund_quality'

# %%
# change empty strings to 0
df["vc_quality_perception"] = df["vc_quality_perception"].replace("", 0)
df["vc_quality_perception"] = df["vc_quality_perception"].astype(float, errors='ignore')
df["proximity"] = df["proximity"].replace("", 0)
df["proximity"] = df["proximity"].astype(float, errors='ignore')

# %%
possible_ranges = {
    "< USD 1mn": 1,
    "USD 5-10mn": 2,
    "USD 10-20mn": 3,
    "> USD 20mn": 4,
}

# check if funding round is inside what range
if inputs["round"]["size"] < 1:
    company_investment_range = "< USD 1mn"
elif inputs["round"]["size"] < 5:
    company_investment_range = ["USD 5-10mn", "< USD 1mn"]
elif inputs["round"]["size"] < 10:
    company_investment_range = ["USD 10-20mn", "USD 5-10mn", "< USD 1mn"]
else:
    company_investment_range = [">USD 20mn", "USD 10-20mn", "USD 5-10mn", "< USD 1mn"]

# remove from the df the rows that are not in the company_investment_range
# Converter a coluna investment_range de string para lista
# remove [ ]
df["investment_range"] = df["investment_range"].apply(lambda x: x.strip("[]"))

company_investment_range_pattern = '|'.join(company_investment_range)

# %%
### FILTERS ###
df = df[df["investment_range"].str.contains(company_investment_range_pattern, na=False)]

if inputs["leader_or_follower"] == "leader":
    # get only leader? that contains the word Leader (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("leader")]
else:
    # get only follower? that contains the word Follower (case insensitive)
    df = df[df["leader?"].str.lower().str.contains("follower")]

if inputs["fund_quality"] == "High":
    df = df[df["vc_quality_perception"] >= 4]
elif inputs["fund_quality"] == "Medium":
    df = df[df["vc_quality_perception"] >= 3]

if inputs["fund_closeness"] == "Close":
    df = df[df["proximity"] >= 3]

# %%
cols_for_ai = ["name", "investment_geography", "prefered_industry_enriched", "description", "observations"]

# %%
# login using service account
from google.oauth2 import service_account
import pandas as pd
import gspread
from gspread_pandas import Spread
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Configurar credenciais
credentials = service_account.Credentials.from_service_account_file(
    ".secrets/service-account-admin.json",
    scopes=['https://www.googleapis.com/auth/spreadsheets', 
            'https://www.googleapis.com/auth/drive']
)

# Conectar ao Google Sheets
gc = gspread.authorize(credentials)

# Extrair o ID da planilha da URL
sheet_id = "11I9QFSMFn7UBfV0wz0-hAYgWtIKytTVnWA9pjquwgdk"

# Abrir a planilha e obter a primeira aba
sheet = gc.open_by_key(sheet_id).sheet1

# Obter todos os dados e converter para DataFrame
data = sheet.get_all_values()
headers = data[0]
df = pd.DataFrame(data[1:], columns=headers)

# Carregar modelo de embeddings
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# Função para criar embeddings das linhas do DataFrame
def create_embeddings(df, text_column):
    # Assumindo que queremos usar uma coluna específica para embeddings
    texts = df[text_column].tolist()
    embeddings = model.encode(texts)
    return embeddings

# Função para buscar entradas similares com base em uma consulta
def search_similar(query, df, embeddings, top_n=5):
    # Criar embedding para a consulta
    query_embedding = model.encode([query])
    
    # Calcular similaridade coseno
    similarities = cosine_similarity(query_embedding, embeddings)[0]
    
    # Obter os índices dos itens mais similares
    top_indices = similarities.argsort()[-top_n:][::-1]
    
    # Criar DataFrame com resultados e pontuações
    results = df.iloc[top_indices].copy()
    results['similarity_score'] = similarities[top_indices]
    
    return results

# Exemplo de uso - selecione a coluna apropriada para criar embeddings
# Substitua 'nome_da_coluna' pela coluna que contém o texto relevante
text_column = 'Título'  # Ajuste conforme necessário
df_embeddings = create_embeddings(df, text_column)

# Exemplo de consulta
exemplo_consulta = "Como criar um bom currículo"
resultados = search_similar(exemplo_consulta, df, df_embeddings)

# Exibir resultados
resultados
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from gspread_pandas import Spread
#       6 import numpy as np
# ----> 7 from sentence_transformers import SentenceTransformer
#       8 from sklearn.metrics.pairwise import cosine_similarity
#      10 # Configurar credenciais
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
sorted_results = sorted(result["fund_scores"], key=lambda x: x.score, reverse=True)
sorted_results
# Out:
# [FundScore(fund_name='Kaszek', score=100.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund perfect for a hot deal). Investment Range: 5 points (USD 10-20mn range is appropriate for leading a $10M Series A). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific notes). Preferred Industry: 8 points (strong alignment with technology and disruption focus - AI Solutions and Food Delivery fit their tech innovation thesis, with their portfolio including marketplaces and software that would apply to Brendi). Description: 2 points (high-impact technology-based companies in Latin America aligns well with Brendi's AI-focused food delivery platform)."),
#  FundScore(fund_name='Monashees', score=92.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund perfect for a hot deal). Investment Range: 5 points (USD 10-20mn range works well for leading a $10M Series A). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific notes). Preferred Industry: 5 points (good alignment with their tech focus including marketplaces, which would apply to food delivery platforms with AI). Description: 3 points (strong fit with their focus on human-centric solutions and innovative ventures, perfect for an AI food delivery platform)."),
#  FundScore(fund_name='Atlantico', score=84.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 4/5 (4 points) - High quality perception suitable for a hot deal. | Investment range: USD 1-5mn, USD 5-10mn (5 points) - Range perfectly fits the $2M commitment in a $10M Series A. | Investment geography: Latam, Brazil (5 points) - Perfect match for Brendi's Brazilian focus. | Funding rounds: Series A, Series B (5 points) - Explicitly targets Series A which matches Brendi's round. | Observations: (2 points) - Interest in technology and consumer digital but no specific AI mention. | Preferred industry: (0 points) - Agnostic approach but mentions e-commerce and food tech in their analysis. | Description match: (0 points) - General focus on 'successful businesses' but no specific mention of AI or food delivery."),
#  FundScore(fund_name='Valor Capital Group', score=80.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund as noted in observations). Investment Range: 4 points (multiple ranges including USD 5-10mn that could work for leading portion of $10M round). Investment Geography: 5 points (Brazil focus perfect match). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific relevant notes for this deal). Preferred Industry: 4 points (some alignment with marketplace platforms, though primary focus is fintech/enterprise/crypto). Description: 2 points (cross-border nature less relevant, but still strong on connecting to US markets which could benefit Brendi)."),
#  FundScore(fund_name='Upload', score=80.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 4/5 (4 points) - High quality perception fitting for a hot deal. | Investment range: USD 1-5mn (4 points) - Range fits the $2M commitment in a $10M Series A. | Investment geography: Global (4 points) - Covers Brazil but not exclusively focused there. | Funding rounds: Regardless (4 points) - Flexible across stages. | Observations: (5 points) - Specifically focuses on AI startups and has explicitly mentioned interest in AI for productivity gains, which perfectly matches Brendi's AI agents for restaurants. | Preferred industry: (3 points) - Their focus on AI and software B2B aligns well with Brendi's offering. | Description match: (0 points) - Limited specific mention of food-tech or delivery solutions in their description."),
#  FundScore(fund_name='Astella', score=76.0, reason="Meeting Frequency: Bimonthly (6 points) - Good closeness for a top fund that user wants and matches 'fund_closeness' of 100%. | VC quality: 4/5 (4 points) - High quality perception makes them a good fit for a 'hot deal'. | Investment range: USD 1-5mn, USD 5-10mn (5 points) - Their USD 1-5mn range fits perfectly with the $2M commitment in a $10M Series A. | Investment geography: Brazil (5 points) - Perfect match for Brendi's Brazilian market focus. | Funding rounds: Series A (5 points) - Explicitly invests in Series A rounds. | Observations: GTM Strategy specialists (3 points) - Valuable expertise for a company looking to disrupt food delivery market. | Preferred industry: (4 points) - While industry-agnostic, they specialize in SaaS and marketplaces which aligns with Brendi's AI platform for restaurants. | Description match: (2 points) - Their focus on 'innovative SaaS, Marketplaces and DTC solutions' matches Brendi's business model."),
#  FundScore(fund_name='big_bets', score=72.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Good quality fund for a promising deal. Investment Range: Limited fit (2pts) - They primarily invest <$1M-5M, which is at the lower end for a $2M lead in a $10M round. Investment Geography: Strong fit (5pts) - Focuses on Brazil and USA, perfect for a Brazilian company. Funding Rounds First Check: Perfect match (5pts) - Series A is explicitly in their focus range. Preferred Industry: Strong match (9pts) - Their focus on AI, SaaS and software aligns perfectly with Brendi's AI agents. Description: Good alignment (3pts) - Their description of partnering with entrepreneurs from Day 1 and supporting next-generation companies fits well with Brendi."),
#  FundScore(fund_name='Alexia Ventures', score=68.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Quality fund appropriate for a promising deal. Investment Range: Good fit (4pts) - Investment range (<$1M-20M) covers the needed $2M lead. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Perfect match (5pts) - Series A is explicitly in their focus range. Preferred Industry: Strong match (8pts) - Their focus on Software Platforms and Data/AI aligns well with Brendi's AI solution. Description: Good alignment (2pts) - They focus on early-stage software and AI startups in Brazil, which perfectly matches Brendi."),
#  FundScore(fund_name='Hi Ventures', score=64.0, reason='Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 4/5 (4 points) - Good quality perception. | Investment range: USD 1-5mn (5 points) - Perfect match for $2M commitment and lead role. | Investment geography: Latam ex-Brazil but looking for Brazil deals (4 points) - Good strategic match. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Not specified but focused on human innovation (2 points) - Potential match. | Description compatibility: Latin American startup focus (3 points) - Regional alignment.'),
#  FundScore(fund_name='Andreessen Horowitz', score=60.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Excellent (5pts) - Top-tier fund appropriate for a 'hot deal'. Investment Range: Good fit (4pts) - They invest $1-20M+ which works well for a $2M lead in a $10M Series A. Investment Geography: Global covers Brazil (3pts) - Not Brazil-specific but invests globally. Funding Rounds First Check: Compatible (4pts) - Invests 'Regardless' of round stage. Preferred Industry: Very strong match (8pts) - Focus on AI and strong fit with Brendi's AI agents technology. Description: Good alignment (1pt) - Their focus on innovative tech startups aligns with Brendi's AI solution."),
#  FundScore(fund_name='ONEVC', score=60.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 5/5 (5 points) - Top-tier fund perception. | Investment range: USD 1-5mn (4 points) - Good match for $2M commitment. | Investment geography: Brazil specifically (5 points) - Perfect match for Brazilian company. | Funding rounds: Pre-Seed, Seed (0 points) - No Series A experience, mismatch with round type. | Preferred industry: Not specified but described as category-defining (3 points) - Potential match. | Description compatibility: Strong Latam tech ecosystem focus (5 points) - Well aligned with Brendi's regional focus."),
#  FundScore(fund_name='Canary', score=56.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (high quality VC). Investment Range: 0 points (USD 1-5mn range is too small to lead a $10M Series A round). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 0 points (Pre-Seed and Seed focus doesn't match Series A need). Observations: 0 points (no specific notes). Preferred Industry: 5 points (good alignment with marketplaces and e-commerce focus that would apply to food delivery). Description: 2 points (their co-founding approach is more suited to earlier stages than Series A)."),
#  FundScore(fund_name='Zenda', score=52.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: <USD 1mn (1 point) - Too small for Series A lead role. | Investment geography: Latam focus (4 points) - Good match for Brazilian company. | Funding rounds: Pre-Seed, Seed (0 points) - No Series A experience, mismatch with round type. | Preferred industry: AI Solutions explicitly mentioned (5 points) - Strong match with Brendi's AI focus. | Description compatibility: B2B tech investments focus (4 points) - Strong alignment with Brendi's B2B restaurant tech solution."),
#  FundScore(fund_name='NXTP Ventures', score=48.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Good quality fund for this deal. Investment Range: Limited fit (2pts) - They invest <$1M-5M, which is on the lower end for a $2M lead in a $10M round. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Good match (4pts) - Series A is in their focus range. Preferred Industry: Some match (3pts) - While they focus on B2B solutions, they don't specifically list AI agents or food delivery. Description: Partial alignment (1pt) - They support high-impact companies but no specific mention of AI or food tech domains."),
#  FundScore(fund_name='Fen Ventures', score=48.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: Unknown (2 points) - Missing data. | Investment geography: Latam ex-Brazil (3 points) - Latam focus but not specifically Brazil. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: AI and Digital Consumer focus (4 points) - Good match with Brendi's AI and consumer tech aspects. | Description compatibility: Early stage VC for tech companies (2 points) - Somewhat aligned."),
#  FundScore(fund_name='Alter Global', score=48.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 3/5 (3 points) - Good but not top-tier quality. | Investment range: < USD 1mn (1 point) - Too small for a $2M commitment in a $10M Series A. | Investment geography: Global, Emerging Markets (3 points) - Includes Brazil but not specifically focused there. | Funding rounds: Pre-Seed, Seed (0 points) - Does not match Series A stage. | Observations: (2 points) - Interest in digitalizing traditional sectors could be relevant. | Preferred industry: (3 points) - B2B focus aligns partially with restaurant management aspect. | Description match: (0 points) - No specific mention of AI or food delivery services."),
#  FundScore(fund_name='Headline', score=44.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: USD 1-5mn (5 points) - Perfect match for $2M commitment and lead role. | Investment geography: Brazil specifically (5 points) - Perfect match for Brazilian company. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Growth-stage Technology (2 points) - Broad match but not specific. | Description compatibility: Global VC with limited tech specifics (0 points) - Limited match with Brendi's specific focus."),
#  FundScore(fund_name='Caravela Capital', score=44.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 3 points (good but not top-tier). Investment Range: 0 points (< USD 1mn range is too small to lead a $10M Series A). Investment Geography: 5 points (Brazil focus is perfect match). Funding Rounds: 0 points (Pre-Seed and Seed focus doesn't match Series A need). Observations: 0 points (no specific notes). Preferred Industry: 4 points (e-commerce and delivery experience with companies like GetNinjas and Mottu aligns well with Brendi's food delivery focus). Description: 2 points (their mentorship and early-stage focus doesn't align perfectly with Series A)."),
#  FundScore(fund_name='Dalus Capital', score=40.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: USD 1-5mn matches Series A (3 points) - Range appropriate but not ideal for leader role as requested. | Investment geography: Latam focus includes Brazil (4 points) - Good match for Brazilian company. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Has AI Solutions via Climate focus but lacks specific food tech (2 points) - Limited industry match. | Description compatibility: Focus on tech solutions with social impact (2 points) - Somewhat aligned with Brendi's mission."),
#  FundScore(fund_name='SaaSholic', score=36.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Average (3pts) - Decent quality fund. Investment Range: Limited fit (2pts) - They invest <$1M-5M, which is at the lower end for a $2M lead in a $10M round. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Poor match (0pts) - They focus on Pre-Seed and Seed, not Series A. Preferred Industry: Some match (3pts) - Focus on SaaS and tech companies but no specific mention of AI or restaurant tech. Description: Good alignment (2pts) - Focus on SaaS and companies with predictable/recurring business models aligns with Brendi's subscription potential."),
#  FundScore(fund_name='DST Global', score=36.0, reason="Meeting Frequency: 6 points (bimonthly meetings align moderately with desired closeness). VC Quality: 5 points (top-tier fund). Investment Range: 5 points (multiple ranges including USD 10-20mn perfect for leading a $10M Series A). Investment Geography: 3 points (global focus includes Brazil but not specific). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific notes). Preferred Industry: 3 points (internet consumer experience applies to food delivery platforms, though primarily later stage). Description: 1 point (fastest growing tech companies focus applies somewhat, but typically for much larger companies)."),
#  FundScore(fund_name='Tidemark', score=32.0, reason='Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 5/5 (5 points) - Top-tier fund perception. | Investment range: USD 5-10mn+ (4 points) - Range appropriate for Series A lead. | Investment geography: Global/USA focus (0 points) - No specific Latam/Brazil focus. | Funding rounds: Series B+ (0 points) - Later stage than Series A. | Preferred industry: Vertical SaaS with restaurant mention (3 points) - Some alignment with restaurant management. | Description compatibility: Growth focus for expanding companies (2 points) - Somewhat aligned.'),
#  FundScore(fund_name='Quona Capital', score=32.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 4 points (good quality VC). Investment Range: 2 points (USD 5-10mn could potentially lead but it's at the lower end for a $10M round). Investment Geography: 3 points (Global, Emerging Markets includes Brazil but not specific). Funding Rounds: 3 points (Series A is in their focus but not their primary stage). Observations: 0 points (no specific notes). Preferred Industry: 0 points (fintech focus doesn't align well with food delivery/AI focus of Brendi). Description: 1 point (financial inclusion focus doesn't match Brendi's business model)."),
#  FundScore(fund_name='J.P. Morgan & Co.', score=32.0, reason="Meeting Frequency: Bimonthly (6 points) - Good closeness but not perfect. | VC quality: Not specified (3 points) - Assumed good based on company reputation. | Investment range: Not specified (2 points) - Unclear if they can lead with $2M. | Investment geography: Global (3 points) - Covers Brazil but not specifically focused there. | Funding rounds: Not specified (1 point) - No clear indication of Series A focus. | Observations: (0 points) - No specific relevant observations. | Preferred industry: (3 points) - Interested in Fintech and AI/data but primarily for finance applications, not food delivery. | Description match: (0 points) - Investment solutions focus doesn't specifically align with Brendi's AI food delivery business."),
#  FundScore(fund_name='Credit Saison', score=28.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: Unknown (1 point) - Missing data, concerning for leader role. | Investment geography: Global (3 points) - Includes Brazil but not specifically focused. | Funding rounds: Pre-Seed, Seed (0 points) - No Series A experience, mismatch with round type. | Preferred industry: E-commerce & Marketplace align partially (3 points) - Some overlap but missing food tech focus. | Description compatibility: Focus on fintech, e-commerce, Web3 (1 point) - Limited match with Brendi's AI and food delivery focus."),
#  FundScore(fund_name='Citrino Ventures', score=24.0, reason='Meeting Frequency: Bimonthly (6pts) - Medium proximity, less than requested. VC Quality: Average (3pts) - Decent but not top-tier fund. Investment Range: Limited fit (2pts) - They invest $1-5M, which is adequate but tight for a $2M lead in a $10M round. Investment Geography: Perfect fit (5pts) - Specifically focused on Brazil. Funding Rounds First Check: Perfect match (5pts) - Series A is explicitly in their focus range. Preferred Industry: Minimal match (1pts) - No specific mention of AI for restaurants or food delivery. Description: Partial alignment (1pts) - Provides hands-on support but no specific industry alignment with Brendi.'),
#  FundScore(fund_name='Magma Partners', score=24.0, reason="Meeting Frequency: 6 points (bimonthly meetings align moderately with desired closeness). VC Quality: 2 points (lower quality perception). Investment Range: 0 points (investment range not specified, likely too small for leading a $10M round). Investment Geography: 3 points (Latam focus includes Brazil). Funding Rounds: 0 points (stage focus not specified). Observations: 0 points (no specific notes). Preferred Industry: 4 points (marketplace focus could apply to food delivery platforms, but not perfect fit). Description: 1 point (technology startups in Latin America is relevant but their specific vertical focus isn't aligned)."),
#  FundScore(fund_name='Flourish Ventures', score=24.0, reason="Meeting Frequency: Bimonthly (6 points) - Good closeness but not perfect. | VC quality: 4/5 (4 points) - High quality perception. | Investment range: USD 1-5mn (4 points) - Fits the $2M commitment in Series A. | Investment geography: Global, Emerging Markets (3 points) - Covers Brazil but not focused. | Funding rounds: Seed, Series A (5 points) - Explicitly mentions Series A. | Observations: (0 points) - No relevant observations. | Preferred industry: (-5 points) - Strictly focused on Fintech, which is only tangentially related to Brendi through 'Embedded Finance' but this is not their core business. | Description match: (0 points) - Focus on financial health doesn't align with Brendi's core food delivery AI business."),
#  FundScore(fund_name='Mira Capital', score=20.0, reason="Meeting Frequency: Quarterly (3 points) - Lower frequency than ideal. | VC quality: Unknown (2 points) - Family office without clear quality metrics. | Investment range: Unknown (2 points) - Missing data on investment range. | Investment geography: Global (3 points) - Includes Brazil but not focused. | Funding rounds: Unknown (0 points) - No data on funding rounds experience. | Preferred industry: AI and Marketplace focus aligns well (4 points) - Good match with Brendi's AI focus. | Description compatibility: Wealth management focus doesn't strongly align (1 point) - Limited relevance to Brendi's technology focus."),
#  FundScore(fund_name='500 Startups', score=20.0, reason="Meeting Frequency: 6 points (bimonthly meetings align moderately with desired closeness). VC Quality: 3 points (assumed average quality based on brand recognition). Investment Range: 0 points (< USD 1mn is far too small to lead a $10M Series A). Investment Geography: 3 points (Global presence includes Brazil). Funding Rounds: 0 points (Pre-Seed focus doesn't match Series A need). Observations: 0 points (no specific notes). Preferred Industry: 4 points (flexible approach across tech sectors would include AI and marketplace solutions). Description: 2 points (focus on supporting talented entrepreneurs aligns with Brendi's young, energetic founder from ITA)."),
#  FundScore(fund_name='HOF Capital', score=16.0, reason="Meeting Frequency: Quarterly (3 points) - Lower frequency than ideal. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: USD 1-5mn (4 points) - Good match for $2M commitment. | Investment geography: Outside Latam (0 points) - Mismatch with Brazilian company. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Fintech focus (0 points) - Not aligned with AI food delivery. | Description compatibility: Tech company focus but fintech-specific (1 point) - Limited match with Brendi's focus."),
#  FundScore(fund_name='Cometa VC', score=16.0, reason="Meeting Frequency: Quarterly (3 points) - Lower closeness than required by user. | VC quality: Not specified (2 points) - Assumed moderate based on observations. | Investment range: Not specified (2 points) - No clear indication if they can lead with $2M. | Investment geography: Spanish-speaking markets, USA (0 points) - Does not align with Brazilian focus. | Funding rounds: Not specified (1 point) - No clear indication of Series A investment. | Observations: (0 points) - No notable observations for this match. | Preferred industry: (5 points) - Focus on technology startups but Hispanic market focus mismatches. | Description match: (1 point) - Technology companies focus aligns somewhat but market focus doesn't match."),
#  FundScore(fund_name='30N Ventures', score=8.0, reason="Meeting Frequency: Bimonthly (6pts) - Medium proximity, less than requested. VC Quality: Below average (2pts) - Lower quality fund not ideal for a hot deal. Investment Range: Good fit (4pts) - Investment range $1-10M fits the $2M lead requirement. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Average match (3pts) - Series A is in their focus range but they're described as a 'follower' while the round needs a leader. Preferred Industry: Minimal match (1pt) - They list foodtech but no specific mention of AI or restaurant tech. Observations: Negative (-4pts) - Described as a 'follower' when a leader is required. Description: Poor alignment (0pt) - No specific mention of AI technologies in their focus areas."),
#  FundScore(fund_name='Across Capital Partners', score=8.0, reason='Meeting Frequency: Bimonthly (6pts) - Medium proximity, less than requested. VC Quality: Strong (4pts) - Quality fund appropriate for a promising deal. Investment Range: Strong fit (5pts) - Investment range $5-20M is perfect for a $2M lead in a $10M round. Investment Geography: Global includes Brazil (3pts) - Not Brazil-specific but global coverage. Funding Rounds First Check: Poor match (0pts) - They focus on Series B and later, not Series A. Preferred Industry: Some match (2pts) - Focus on technology but not specifically AI or food delivery. Description: Partial alignment (1pt) - They support scaling technology businesses but no specific AI focus mentioned.'),
#  FundScore(fund_name='Propel Venture Partners', score=8.0, reason="Meeting Frequency: 6 points (bimonthly meetings align moderately with desired closeness). VC Quality: 3 points (decent quality). Investment Range: 0 points (USD 1-5mn is too small to lead a $10M Series A). Investment Geography: 2 points (Global, US focus less focused on Brazil). Funding Rounds: 3 points (includes Series A but with smaller check sizes). Observations: 0 points (no specific notes). Preferred Industry: -1 points (exclusively focused on fintech and financial services, misaligned with Brendi's core food delivery business). Description: 0 points (fintech and web3 focus doesn't match Brendi's AI food delivery platform)."),
#  FundScore(fund_name='Amador', score=4.0, reason='Meeting Frequency: Bimonthly (6pts) - Medium proximity, less than requested. VC Quality: Below average (2pts) - Lower quality fund not ideal for a hot deal. Investment Range: Poor fit (0pts) - They invest <$1M, which is insufficient for a $2M lead in a $10M round. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Poor match (0pts) - They focus on Pre-Seed and Seed, not Series A. Preferred Industry: Minimal match (1pt) - No specific mention of AI or restaurant tech. Description: Partial alignment (1pt) - Focus on digital-enabled businesses but no specific AI focus.'),
#  FundScore(fund_name='Volpe Capital', score=0.0, reason="Meeting Frequency: Quarterly (3pts) - Lower proximity than requested. VC Quality: Average (3pts) - Described as 'not very smart' with 'low activity'. Investment Range: Good fit (4pts) - Investment range $1-10M fits the $2M lead requirement. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Good match (4pts) - Series A is in their focus range. Preferred Industry: Minimal match (1pt) - No specific mention of AI or restaurant tech, though they do list e-commerce. Observations: Negative (- 5pts) - 'Not very smart' and 'low activity' are significant drawbacks for what's described as a hot deal. Description: Poor alignment (0pts) - Generic description without specifics that match Brendi's focus.")]

# %%
import math
to_keep = parameters["surviving_percentage"]*len(result["fund_scores"])
to_keep = math.ceil(to_keep)
to_keep
# Out:
# 19

# %%
kept_funds = sorted_results[:to_keep]
kept_funds
# Out:
# [FundScore(fund_name='Kaszek', score=100.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund perfect for a hot deal). Investment Range: 5 points (USD 10-20mn range is appropriate for leading a $10M Series A). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific notes). Preferred Industry: 8 points (strong alignment with technology and disruption focus - AI Solutions and Food Delivery fit their tech innovation thesis, with their portfolio including marketplaces and software that would apply to Brendi). Description: 2 points (high-impact technology-based companies in Latin America aligns well with Brendi's AI-focused food delivery platform)."),
#  FundScore(fund_name='Monashees', score=92.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund perfect for a hot deal). Investment Range: 5 points (USD 10-20mn range works well for leading a $10M Series A). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific notes). Preferred Industry: 5 points (good alignment with their tech focus including marketplaces, which would apply to food delivery platforms with AI). Description: 3 points (strong fit with their focus on human-centric solutions and innovative ventures, perfect for an AI food delivery platform)."),
#  FundScore(fund_name='Atlantico', score=84.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 4/5 (4 points) - High quality perception suitable for a hot deal. | Investment range: USD 1-5mn, USD 5-10mn (5 points) - Range perfectly fits the $2M commitment in a $10M Series A. | Investment geography: Latam, Brazil (5 points) - Perfect match for Brendi's Brazilian focus. | Funding rounds: Series A, Series B (5 points) - Explicitly targets Series A which matches Brendi's round. | Observations: (2 points) - Interest in technology and consumer digital but no specific AI mention. | Preferred industry: (0 points) - Agnostic approach but mentions e-commerce and food tech in their analysis. | Description match: (0 points) - General focus on 'successful businesses' but no specific mention of AI or food delivery."),
#  FundScore(fund_name='Valor Capital Group', score=80.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (top-tier fund as noted in observations). Investment Range: 4 points (multiple ranges including USD 5-10mn that could work for leading portion of $10M round). Investment Geography: 5 points (Brazil focus perfect match). Funding Rounds: 5 points (invests 'Regardless' of stage, including Series A). Observations: 0 points (no specific relevant notes for this deal). Preferred Industry: 4 points (some alignment with marketplace platforms, though primary focus is fintech/enterprise/crypto). Description: 2 points (cross-border nature less relevant, but still strong on connecting to US markets which could benefit Brendi)."),
#  FundScore(fund_name='Upload', score=80.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 4/5 (4 points) - High quality perception fitting for a hot deal. | Investment range: USD 1-5mn (4 points) - Range fits the $2M commitment in a $10M Series A. | Investment geography: Global (4 points) - Covers Brazil but not exclusively focused there. | Funding rounds: Regardless (4 points) - Flexible across stages. | Observations: (5 points) - Specifically focuses on AI startups and has explicitly mentioned interest in AI for productivity gains, which perfectly matches Brendi's AI agents for restaurants. | Preferred industry: (3 points) - Their focus on AI and software B2B aligns well with Brendi's offering. | Description match: (0 points) - Limited specific mention of food-tech or delivery solutions in their description."),
#  FundScore(fund_name='Astella', score=76.0, reason="Meeting Frequency: Bimonthly (6 points) - Good closeness for a top fund that user wants and matches 'fund_closeness' of 100%. | VC quality: 4/5 (4 points) - High quality perception makes them a good fit for a 'hot deal'. | Investment range: USD 1-5mn, USD 5-10mn (5 points) - Their USD 1-5mn range fits perfectly with the $2M commitment in a $10M Series A. | Investment geography: Brazil (5 points) - Perfect match for Brendi's Brazilian market focus. | Funding rounds: Series A (5 points) - Explicitly invests in Series A rounds. | Observations: GTM Strategy specialists (3 points) - Valuable expertise for a company looking to disrupt food delivery market. | Preferred industry: (4 points) - While industry-agnostic, they specialize in SaaS and marketplaces which aligns with Brendi's AI platform for restaurants. | Description match: (2 points) - Their focus on 'innovative SaaS, Marketplaces and DTC solutions' matches Brendi's business model."),
#  FundScore(fund_name='big_bets', score=72.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Good quality fund for a promising deal. Investment Range: Limited fit (2pts) - They primarily invest <$1M-5M, which is at the lower end for a $2M lead in a $10M round. Investment Geography: Strong fit (5pts) - Focuses on Brazil and USA, perfect for a Brazilian company. Funding Rounds First Check: Perfect match (5pts) - Series A is explicitly in their focus range. Preferred Industry: Strong match (9pts) - Their focus on AI, SaaS and software aligns perfectly with Brendi's AI agents. Description: Good alignment (3pts) - Their description of partnering with entrepreneurs from Day 1 and supporting next-generation companies fits well with Brendi."),
#  FundScore(fund_name='Alexia Ventures', score=68.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Quality fund appropriate for a promising deal. Investment Range: Good fit (4pts) - Investment range (<$1M-20M) covers the needed $2M lead. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Perfect match (5pts) - Series A is explicitly in their focus range. Preferred Industry: Strong match (8pts) - Their focus on Software Platforms and Data/AI aligns well with Brendi's AI solution. Description: Good alignment (2pts) - They focus on early-stage software and AI startups in Brazil, which perfectly matches Brendi."),
#  FundScore(fund_name='Hi Ventures', score=64.0, reason='Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 4/5 (4 points) - Good quality perception. | Investment range: USD 1-5mn (5 points) - Perfect match for $2M commitment and lead role. | Investment geography: Latam ex-Brazil but looking for Brazil deals (4 points) - Good strategic match. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Not specified but focused on human innovation (2 points) - Potential match. | Description compatibility: Latin American startup focus (3 points) - Regional alignment.'),
#  FundScore(fund_name='Andreessen Horowitz', score=60.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Excellent (5pts) - Top-tier fund appropriate for a 'hot deal'. Investment Range: Good fit (4pts) - They invest $1-20M+ which works well for a $2M lead in a $10M Series A. Investment Geography: Global covers Brazil (3pts) - Not Brazil-specific but invests globally. Funding Rounds First Check: Compatible (4pts) - Invests 'Regardless' of round stage. Preferred Industry: Very strong match (8pts) - Focus on AI and strong fit with Brendi's AI agents technology. Description: Good alignment (1pt) - Their focus on innovative tech startups aligns with Brendi's AI solution."),
#  FundScore(fund_name='ONEVC', score=60.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 5/5 (5 points) - Top-tier fund perception. | Investment range: USD 1-5mn (4 points) - Good match for $2M commitment. | Investment geography: Brazil specifically (5 points) - Perfect match for Brazilian company. | Funding rounds: Pre-Seed, Seed (0 points) - No Series A experience, mismatch with round type. | Preferred industry: Not specified but described as category-defining (3 points) - Potential match. | Description compatibility: Strong Latam tech ecosystem focus (5 points) - Well aligned with Brendi's regional focus."),
#  FundScore(fund_name='Canary', score=56.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 5 points (high quality VC). Investment Range: 0 points (USD 1-5mn range is too small to lead a $10M Series A round). Investment Geography: 5 points (Latam focus perfect for Brazilian company). Funding Rounds: 0 points (Pre-Seed and Seed focus doesn't match Series A need). Observations: 0 points (no specific notes). Preferred Industry: 5 points (good alignment with marketplaces and e-commerce focus that would apply to food delivery). Description: 2 points (their co-founding approach is more suited to earlier stages than Series A)."),
#  FundScore(fund_name='Zenda', score=52.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: <USD 1mn (1 point) - Too small for Series A lead role. | Investment geography: Latam focus (4 points) - Good match for Brazilian company. | Funding rounds: Pre-Seed, Seed (0 points) - No Series A experience, mismatch with round type. | Preferred industry: AI Solutions explicitly mentioned (5 points) - Strong match with Brendi's AI focus. | Description compatibility: B2B tech investments focus (4 points) - Strong alignment with Brendi's B2B restaurant tech solution."),
#  FundScore(fund_name='NXTP Ventures', score=48.0, reason="Meeting Frequency: Monthly (10pts) - Perfect match for requested high proximity. VC Quality: Strong (4pts) - Good quality fund for this deal. Investment Range: Limited fit (2pts) - They invest <$1M-5M, which is on the lower end for a $2M lead in a $10M round. Investment Geography: Good fit (4pts) - Focuses on Latam including Brazil. Funding Rounds First Check: Good match (4pts) - Series A is in their focus range. Preferred Industry: Some match (3pts) - While they focus on B2B solutions, they don't specifically list AI agents or food delivery. Description: Partial alignment (1pt) - They support high-impact companies but no specific mention of AI or food tech domains."),
#  FundScore(fund_name='Fen Ventures', score=48.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: Unknown (2 points) - Missing data. | Investment geography: Latam ex-Brazil (3 points) - Latam focus but not specifically Brazil. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: AI and Digital Consumer focus (4 points) - Good match with Brendi's AI and consumer tech aspects. | Description compatibility: Early stage VC for tech companies (2 points) - Somewhat aligned."),
#  FundScore(fund_name='Alter Global', score=48.0, reason="Meeting Frequency: Monthly (10 points) - Excellent closeness matching user's 100% requirement. | VC quality: 3/5 (3 points) - Good but not top-tier quality. | Investment range: < USD 1mn (1 point) - Too small for a $2M commitment in a $10M Series A. | Investment geography: Global, Emerging Markets (3 points) - Includes Brazil but not specifically focused there. | Funding rounds: Pre-Seed, Seed (0 points) - Does not match Series A stage. | Observations: (2 points) - Interest in digitalizing traditional sectors could be relevant. | Preferred industry: (3 points) - B2B focus aligns partially with restaurant management aspect. | Description match: (0 points) - No specific mention of AI or food delivery services."),
#  FundScore(fund_name='Headline', score=44.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: USD 1-5mn (5 points) - Perfect match for $2M commitment and lead role. | Investment geography: Brazil specifically (5 points) - Perfect match for Brazilian company. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Growth-stage Technology (2 points) - Broad match but not specific. | Description compatibility: Global VC with limited tech specifics (0 points) - Limited match with Brendi's specific focus."),
#  FundScore(fund_name='Caravela Capital', score=44.0, reason="Meeting Frequency: 10 points (monthly meetings align with desired 100% closeness). VC Quality: 3 points (good but not top-tier). Investment Range: 0 points (< USD 1mn range is too small to lead a $10M Series A). Investment Geography: 5 points (Brazil focus is perfect match). Funding Rounds: 0 points (Pre-Seed and Seed focus doesn't match Series A need). Observations: 0 points (no specific notes). Preferred Industry: 4 points (e-commerce and delivery experience with companies like GetNinjas and Mottu aligns well with Brendi's food delivery focus). Description: 2 points (their mentorship and early-stage focus doesn't align perfectly with Series A)."),
#  FundScore(fund_name='Dalus Capital', score=40.0, reason="Meeting Frequency: Bimonthly (6 points) - Good frequency for proximity requirement. | VC quality: 3/5 (3 points) - Average quality perception. | Investment range: USD 1-5mn matches Series A (3 points) - Range appropriate but not ideal for leader role as requested. | Investment geography: Latam focus includes Brazil (4 points) - Good match for Brazilian company. | Funding rounds: Series A experience (5 points) - Perfect match for round type. | Preferred industry: Has AI Solutions via Climate focus but lacks specific food tech (2 points) - Limited industry match. | Description compatibility: Focus on tech solutions with social impact (2 points) - Somewhat aligned with Brendi's mission.")]

# %%
doc_plaintext
# Out:
# 'Analysis of Venture Capital Investment Preferences in Latin America\n1. Executive Summary\nThis report analyzes the preferred investment industries of a selected group of venture capital firms with a significant presence or interest in the Latin American market. The analysis reveals a strong concentration of investment in the technology sector, particularly within software-as-a-service (SaaS), financial technology (Fintech), and e-commerce enablers. While many firms exhibit a broad interest across various technology verticals, some demonstrate specialization in areas such as agritech, edtech, and climate technology. The findings highlight the dynamism and increasing maturity of the Latin American venture capital ecosystem, attracting both regional and global investors who are keen to capitalize on the region\'s burgeoning entrepreneurial landscape. Understanding these investment preferences is crucial for entrepreneurs seeking funding and for investors looking to identify key opportunities within this rapidly evolving market.\n2. Introduction: The Latin American Venture Capital Landscape\nThe venture capital ecosystem in Latin America has experienced significant growth and transformation in recent years, evolving from a nascent stage to a vibrant and increasingly attractive destination for global capital. The period around 2021 and 2022 marked a substantial inflection point, with investment volumes reaching unprecedented levels, dwarfing the cumulative investments of the preceding decade . This surge in activity underscores the growing recognition of the immense potential within the Latin American startup scene. However, it is crucial to acknowledge the inherent diversity of this landscape. What might prove successful in the Brazilian market, the largest in the region, may not necessarily translate to the unique dynamics of Mexico or the Spanish-speaking nations . Each country possesses its own distinct market characteristics, regulatory frameworks, and consumer behaviors, necessitating a nuanced understanding for effective investment strategies. This report delves into the investment preferences of several key venture capital firms active in Latin America, aiming to provide a comprehensive overview of the current trends and areas of focus within this dynamic ecosystem.  \n3. Investment Preferences of Key Venture Capital Firms in Latin America\n3.1. Bridge Latam\nEstablished in 2021 and headquartered in Mexico City, Bridge Latam operates as a venture capital investment firm with a clear focus on early-stage startups within the Latin American technology sector . The firm\'s emergence during a period of heightened venture capital activity in the region signifies the ongoing expansion of the investment landscape and the creation of new avenues for entrepreneurs seeking early funding. Bridge Latam\'s investment portfolio reveals a particular interest in sectors such as Business/Productivity Software, Financial Software, and Human Capital Services . This indicates a belief in the potential of technology to drive efficiency and innovation across various enterprise functions. Beyond its direct venture investments, Bridge Latam\'s involvement in market analysis, sourcing, and business development across Consumer Goods, Luxury Goods, and Capital Goods suggests a broader understanding of the Latin American market. This connection could imply a strategic approach to identifying and supporting technology solutions that can effectively address the needs and challenges within these more traditional industries. The firm\'s investment thesis centers on backing startups that demonstrate strong technological potential and the capacity for significant scalability, with a notable emphasis on the quality and vision of the founding team . With typical initial investments ranging from USD $200,000 to USD $500,000 , Bridge Latam positions itself as a key supporter of early-stage innovation in Latin America. In essence, Bridge Latam is an early-stage ...

# %%
fund_names = []
for fund in kept_funds:
    fund_names.append(fund.fund_name)
fund_names
# Out:
# ['Kaszek',
#  'Monashees',
#  'Valor Capital Group',
#  'Upload',
#  'ONEVC',
#  'Atlantico',
#  'Alexia Ventures',
#  'Hi Ventures',
#  'Andreessen Horowitz',
#  'Zenda',
#  'Astella',
#  'big_bets',
#  'Headline',
#  'Fen Ventures',
#  'Caravela Capital',
#  'Dalus Capital',
#  'Canary',
#  'Quona Capital',
#  'SaaSholic']

# %%
df_first_filter = df[df["name"].isin(fund_names)]
df_first_filter.head(2)
# Out:
#                   name                                      Opiniao Pedro  \
# 2  Andreessen Horowitz  Lots of money, hyped, low activity in Brazil. ...
# 3             big_bets  Pure software, they don't like hardware. Rarel...
#
#   Opiniao Gus industry_agnostic              leader? investment_geography  \
# 2                          TRUE  Leader and Follower               Global
# 3                                Leader and Follower          Brazil, USA
#
#   preferred_industry vc_quality_perception                observations  \
# 2                 []                   5.0  Focusing more on Series A+
# 3                 []                   4.0    Brazil and Global thesis
#
#                                    investment_range  ...   Opiniao Cache  \
# 2  [USD 1-5mn, USD 5-10mn, USD 10-20mn, > USD 20mn]  ...
# 3                            [< USD 1mn, USD 1-5mn]  ...
#
#   investor_profile                         prefered_industry_enriched  \
# 2               VC  (Global: AI, Bio + Healthcare, Consumer, Crypt...
# 3               VC  Software (IDtech, AI, SaaS, Fintech, Edtech, G...
#
#   meeting_frequency intros_made intros_received  \
# 2         [Monthly]        14.0             3.0
# 3         [Monthly]        18.0            44.0
#
#                                          description         domains  \
# 2  Andreessen Horowitz is a venture capital firm ...        a16z.com
# 3  big_bets is a venture capital and private equi...  bigbets.com.br
#
#                                entry_id
# 2  082a298f-a986-4686-becb-9905d63a806b
# 3  0920744a-6cdf-4992-9ecd-f370cb240be6
#
# [2 rows x 22 columns]
